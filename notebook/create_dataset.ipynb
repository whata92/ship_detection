# %%
import os
import glob

# %%
data_root = "/workspace/dataset/LS-SSDD-v1.0-OPEN/JPEGImages_sub"

# %%
img_list = glob.glob(
    os.path.join(data_root, "*.jpg")
)
img_list
# Out:
# ['/workspace/dataset/LS-SSDD-v1.0-OPEN/JPEGImages_sub/01_2_16.jpg',
#  '/workspace/dataset/LS-SSDD-v1.0-OPEN/JPEGImages_sub/08_19_27.jpg',
#  '/workspace/dataset/LS-SSDD-v1.0-OPEN/JPEGImages_sub/01_10_13.jpg',
#  '/workspace/dataset/LS-SSDD-v1.0-OPEN/JPEGImages_sub/06_16_10.jpg',
#  '/workspace/dataset/LS-SSDD-v1.0-OPEN/JPEGImages_sub/10_20_18.jpg',
#  '/workspace/dataset/LS-SSDD-v1.0-OPEN/JPEGImages_sub/04_5_26.jpg',
#  '/workspace/dataset/LS-SSDD-v1.0-OPEN/JPEGImages_sub/15_17_24.jpg',
#  '/workspace/dataset/LS-SSDD-v1.0-OPEN/JPEGImages_sub/13_20_30.jpg',
#  '/workspace/dataset/LS-SSDD-v1.0-OPEN/JPEGImages_sub/13_1_15.jpg',
#  '/workspace/dataset/LS-SSDD-v1.0-OPEN/JPEGImages_sub/07_18_30.jpg',
#  '/workspace/dataset/LS-SSDD-v1.0-OPEN/JPEGImages_sub/03_9_8.jpg',
#  '/workspace/dataset/LS-SSDD-v1.0-OPEN/JPEGImages_sub/14_11_27.jpg',
#  '/workspace/dataset/LS-SSDD-v1.0-OPEN/JPEGImages_sub/07_6_15.jpg',
#  '/workspace/dataset/LS-SSDD-v1.0-OPEN/JPEGImages_sub/02_20_2.jpg',
# ...

# %%
output = "/workspace/dataset/infer_all.txt"
with open(output, "w") as fp:
    fp.write("\n".join(img_list))
